# %% [markdown]
# <a href="https://colab.research.google.com/github/fidanfatih/Web_Scraping/blob/main/BeautifulSoup_Mediamarkt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import html5lib
import pandas as pd

url="https://www.mediamarkt.nl/nl/category/_laptops-482723.html?searchParams=&sort=&view=&page="
comp_name,price, description =[],[],[]

for page in range(1,21):
  html = requests.get(url + str(page)).content
  soup=BeautifulSoup(html,"html.parser")

  liste=soup.find_all("div",{"class":"product-wrapper"})

  for i in liste:
    price.append(i.find("div",{"class":"price small"}).text.strip("-,"))
    comp_name.append(i.h2.text.strip().split("-")[0])
    details_title =i.find("dl",{"class":"product-details"}).find_all("dt")
    details =i.find("dl",{"class":"product-details"}).find_all("dd")
    merge=[]
    for s1,s2 in zip(details_title,details):
      merge.append(s1.text + s2.text)
    description.append(''.join(merge))

keys=['comp_name',
      'price',
      'description']
values=[comp_name,
        price, 
        description]
dictionary = dict(zip(keys, values))

df = pd.DataFrame.from_dict(dictionary)
df
# Out:
#                                       comp_name  ...                                        description
# 0                APPLE MacBook Air 13.3 (2020)   ...  Beeldschermdiagonaal (cm/inch):33.8 cm / 13.3 ...
# 1                APPLE MacBook Air 13.3 (2020)   ...  Beeldschermdiagonaal (cm/inch):33.8 cm / 13.3 ...
# 2                       HP Chromebook x360 (14a  ...  Beeldschermdiagonaal (cm/inch):35.6 cm / 14 in...
# 3              ACER Chromebook Spin 513 (R841LT  ...  Beeldschermdiagonaal (cm/inch):33.8 cm / 13.3 ...
# 4                            HP Chromebook (14a  ...  Beeldschermdiagonaal (cm/inch):35.6 cm / 14 in...
# ..                                          ...  ...                                                ...
# 463               ASUS Vivobook 15 OLED (M513UA  ...  Beeldschermdiagonaal (cm/inch):39.6 cm / 15.6 ...
# 464                  ASUS Chromebook (CX1100CNA  ...  Beeldschermdiagonaal (cm/inch):29.5 cm / 11.6 ...
# ...
