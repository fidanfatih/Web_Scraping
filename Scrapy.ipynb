# %%
import pandas as pd

# %%
pd.read_json('Data/autoscout_data.json')
# Out:
#            country      title  \
# 0      Netherlands    Audi A3
# 1      Netherlands    Audi A6
# 2      Netherlands    Audi A1
# 3      Netherlands    Audi A1
# 4      Netherlands    Audi A1
# ...            ...        ...
# 21305       France  Volvo V60
# 21306       France  Volvo V40
# 21307       France  Volvo V40
# 21308       France  Volvo V40
# 21309       France  Volvo V40
#
#                                        short_description price          km  \
# 0      Sportback 1.6 TDI 5drs Clima Attraction Busine...   € 5  274,140 km
# 1      2.0 TFSI Business Edition | Automaat | Navigat...   € 8  177,654 km
# 2      Sportback 1.2 TFSI 86pk Attraction Pro Line Bu...  € 12   51,445 km
# 3      Sportback 1.0 TFSI Pro Line, 5 Drs, Airco, Nav...  € 13   78,562 km
# 4      SPORTBACK 1.2 TFSI S-Line Admired [ Navi Cruis...  € 13   58,662 km
# ...                                                  ...   ...         ...
# ...

# %%
pd.read_json('Data/autoscout_data.json')
