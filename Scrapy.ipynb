# %%
import pandas as pd
pd.set_option('display.width', 400)
pd.set_option('display.max_columns', 50)

df = pd.read_csv('Data/autoscout_data.csv')
df
# Out:
#            country      title                                  short_description     price          km registration      kw      hp                transmission  type previous_owners next_inspection inspection_new   warranty  full_service last_service_date  non_smoking_vehicle last_timing_belt_service_date gearing_type gears       gear_type displacement Cylinders    weight drive chain  \
# 0      Netherlands    Audi A5                 Sportback 1.8 TFSI 170pk 2x S-Line  € 14,850  179,851 km      01/2013  125 kW  170 hp  Used, Full Service History  Used            None            None            Yes       None             1              None                    0                          None    Automatic     1       Automatic     1,798 cc         4  1,500 kg        None
# ...

# %%
pd.read_json('Data/sofifa_data.json')
# Out:
#                        player_name  age height  weight  overall_rating  \
# 0                       Arda Turan   33  5'10"     168              72
# 1                      Adam Hložek   17   6'2"     190              74
# 2                  Alphonso Davies   19   6'0"     165              81
# 3    Nuno Alexandre Tavares Mendes   18   5'9"     154              77
# 4               Alessandro Bastoni   21   6'3"     165              78
# ..                             ...  ...    ...     ...             ...
# 293                   Philipp Lahm   32   5'7"     146              88
# 294                  Billy Gilmour   19   5'7"     146              71
# 295                     Zac McGraw   23   6'4"     205              60
# 296                 Famana Quizera   18   5'8"     154              62
# 297                 Dušan Vlahović   20   6'3"     165              75
#
#      potential   value    wage preferred_food  weak_food  ...  composure  \
# ...
